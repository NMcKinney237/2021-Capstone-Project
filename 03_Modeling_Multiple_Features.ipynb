# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # **Capstone Project: Audio Classification Of Emotions**
#
# # Modeling on MFCC

# %%
#Mount Drive

from google.colab import drive
drive.mount('/content/My_Drive/')
# Out:
# Drive already mounted at /content/My_Drive/; to attempt to forcibly remount, call drive.mount("/content/My_Drive/", force_remount=True).

# %% [markdown]
# ## Imports

# %%
#Import basic, plotting libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns


# %matplotlib inline

#Import SK-Learn Libraries
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier as R_Forest
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier as KNNClassifier
from sklearn import svm
from sklearn.preprocessing import LabelEncoder, StandardScaler, RobustScaler

#Import Keras Layers
import keras
from keras import layers
from keras import models
from keras.layers import GlobalAveragePooling1D, Dense, MaxPooling1D, Conv1D, Flatten, Dropout
from keras.models import Sequential
from keras.layers.core import Activation, Dense 
from keras.layers import BatchNormalization
from tensorflow.keras.optimizers import RMSprop
from keras.layers import GaussianNoise

# %% [markdown]
# ## Functions

# %%
def cf_matrix(y_preds, y_test):
  '''This function creates a confusion matrix on our data'''
  
  cf_matrix = confusion_matrix(y_preds, y_test)
  cmn = cf_matrix.astype('float') / cf_matrix.sum(axis=1)[:, np.newaxis]
  fig, ax = plt.subplots(figsize=(10,10))
  labels = ['Angry', 'Calm', 'Disgust', 'Fearful', 'Happy', 'Neutral', 'Sad', 'Suprised']
  sns.heatmap(cmn, linewidths=1, annot=True, ax=ax, fmt='.2f', cmap="OrRd")
  ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix')
  ax.xaxis.set_ticklabels(labels); ax.yaxis.set_ticklabels(labels);

# %%
#Set a random seed for reproducibility.
np.random.seed(42)

# %%
#Read_CSV
df = pd.read_csv('Data/DataFrames/RAVDESS_Data.csv')

# %%
#Encoded Labels
levels = ['Angry', 'Calm', 'Disgust', 'Fearful', 'Happy', 'Neutral', 'Sad', 'Suprised']

#Show dataframe
df.head(2)
# Out:
#                        path  actor  ...       179           180
# 0  03-01-05-01-02-01-16.wav     16  ...  0.000016  8.843753e-07
# 1  03-01-06-01-02-02-16.wav     16  ...  0.000005  4.393639e-07
#
# [2 rows x 191 columns]

# %%
le = LabelEncoder()
df['encoded_label']= le.fit_transform(df['label'])

# %%
#Select X and y features
X = df.iloc[:, 10:].values
y = df['encoded_label'].values

print(X.shape)
print(y.shape)
# Out:
# (1440, 181)
# (1440,)

# %%
#Add as array
X = np.asarray(X)
y = np.asarray(y)


X.shape, y.shape
# Out:
# ((1440, 181), (1440,))

# %%
#Create train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, shuffle = True)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1080, 181), (1080,), (360, 181), (360,))

# %%
#Scale X_training Data
sc = StandardScaler()

X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
#Expand dimensions for nueral net
X_train_sc_1 = np.expand_dims(X_train_sc, axis=2)
X_test_sc_1 = np.expand_dims(X_test_sc, axis=2)

X_train_sc_1.shape, X_test_sc_1.shape
# Out:
# ((1080, 181, 1), (360, 181, 1))

# %% [markdown]
# ## Models

# %%
SVM = svm.SVC()

# %%
SVM.fit(X_train_sc, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_predSVM = SVM.predict(X_test_sc)

# %%
print(classification_report(y_test,y_predSVM,target_names=levels))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.69      0.52      0.60        48
#         Calm       0.63      0.76      0.69        51
#      Disgust       0.53      0.58      0.55        48
#      Fearful       0.76      0.40      0.53        47
#        Happy       0.42      0.31      0.35        49
#      Neutral       0.00      0.00      0.00        26
#          Sad       0.29      0.63      0.40        41
#     Suprised       0.59      0.68      0.63        50
#
#     accuracy                           0.52       360
#    macro avg       0.49      0.49      0.47       360
# weighted avg       0.52      0.52      0.50       360
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cf_matrix(y_predSVM,y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """

# %% [markdown]
# #### K-Nearest Neighbors

# %%
clf = KNNClassifier()
clf.fit(X_train_sc, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_predKNN = clf.predict(X_test_sc)

# %%
print(classification_report(y_test,y_predKNN,target_names=levels))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.58      0.62      0.60        48
#         Calm       0.66      0.84      0.74        51
#      Disgust       0.60      0.60      0.60        48
#      Fearful       0.49      0.45      0.47        47
#        Happy       0.45      0.35      0.39        49
#      Neutral       0.39      0.42      0.41        26
#          Sad       0.52      0.34      0.41        41
#     Suprised       0.59      0.70      0.64        50
#
#     accuracy                           0.56       360
#    macro avg       0.54      0.54      0.53       360
# weighted avg       0.55      0.56      0.55       360

# %%
cf_matrix(y_predKNN,y_test)

# %% [markdown]
# #### Random Forest Classifier

# %%
rforest = R_Forest(criterion="gini", 
                   max_depth=5, 
                   max_features="log2",  
                   min_samples_leaf = 3, 
                   min_samples_split = 20, 
                   n_estimators= 22000, 
                   )

# %%
#Fit Random forest
rforest.fit(X_train_sc, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=5, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=3, min_samples_split=20,
#                        min_weight_fraction_leaf=0.0, n_estimators=22000,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#Get predictions
y_pred = rforest.predict(X_test_sc)

# %%
#Print classification report
print(classification_report(y_test,y_pred,target_names=levels))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.80      0.50      0.62        48
#         Calm       0.47      0.84      0.61        51
#      Disgust       0.39      0.54      0.46        48
#      Fearful       0.66      0.45      0.53        47
#        Happy       0.36      0.29      0.32        49
#      Neutral       0.00      0.00      0.00        26
#          Sad       0.28      0.29      0.29        41
#     Suprised       0.46      0.54      0.50        50
#
#     accuracy                           0.46       360
#    macro avg       0.43      0.43      0.41       360
# weighted avg       0.46      0.46      0.44       360
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Plot confusion matrix
cf_matrix(y_pred,y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """

# %% [markdown]
# #### Decision Tree Classifier

# %%
#Instantiate decision tree 
dtree = DecisionTreeClassifier()

# %%
#Fit decision tree
dtree.fit(X_train_sc, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#Predict data
y_preds = dtree.predict(X_test_sc)

# %%
#Print classification report
print(classification_report(y_test,y_preds,target_names=levels))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.53      0.58      0.55        48
#         Calm       0.50      0.45      0.47        51
#      Disgust       0.38      0.33      0.36        48
#      Fearful       0.45      0.43      0.44        47
#        Happy       0.39      0.37      0.38        49
#      Neutral       0.21      0.23      0.22        26
#          Sad       0.28      0.34      0.31        41
#     Suprised       0.42      0.42      0.42        50
#
#     accuracy                           0.41       360
#    macro avg       0.40      0.39      0.39       360
# weighted avg       0.41      0.41      0.41       360

# %%
#Plot confusion matrix
cf_matrix(y_preds,y_test)

# %% [markdown]
# #### Convolutional Nueral Net (CNN)

# %%
#Develop model
model = models.Sequential()
model.add(Conv1D(264, kernel_size=5, strides=1,  activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(MaxPooling1D(pool_size=5, strides = 2))
model.add(GaussianNoise(0.1))
model.add(Conv1D(128, kernel_size=5, strides=1, activation='relu'))
model.add(Dropout(0.2))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(8, activation='softmax'))


 # Select loss function and optimizer
model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='rmsprop', 
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 177, 264)          1584
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 177, 264)          0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 87, 264)           0
# _________________________________________________________________
# gaussian_noise_2 (GaussianNo (None, 87, 264)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 83, 128)           169088
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 83, 128)           0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 10624)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                680000
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 520
# =================================================================
# Total params: 851,192
# Trainable params: 851,192
# Non-trainable params: 0
# _________________________________________________________________

# %%
#fit and train model
history = model.fit(
    X_train_sc_1,
    y_train,
    epochs=60,
    batch_size=15,
    validation_data=(X_test_sc_1, y_test)
  )
# Out:
# Epoch 1/60
# 72/72 [==============================] - 6s 78ms/step - loss: 1.9407 - accuracy: 0.2509 - val_loss: 1.7847 - val_accuracy: 0.3528
# Epoch 2/60
# 72/72 [==============================] - 6s 77ms/step - loss: 1.6931 - accuracy: 0.3750 - val_loss: 1.7555 - val_accuracy: 0.3639
# Epoch 3/60
# 72/72 [==============================] - 6s 77ms/step - loss: 1.5392 - accuracy: 0.4083 - val_loss: 1.8435 - val_accuracy: 0.3917
# Epoch 4/60
# 72/72 [==============================] - 5s 76ms/step - loss: 1.4543 - accuracy: 0.4537 - val_loss: 1.7942 - val_accuracy: 0.3944
# Epoch 5/60
# 72/72 [==============================] - 5s 76ms/step - loss: 1.3747 - accuracy: 0.4787 - val_loss: 1.8303 - val_accuracy: 0.4000
# Epoch 6/60
# 72/72 [==============================] - 5s 76ms/step - loss: 1.2973 - accuracy: 0.5259 - val_loss: 1.8066 - val_accuracy: 0.4389
# Epoch 7/60
# 72/72 [==============================] - 5s 76ms/step - loss: 1.2563 - accuracy: 0.5204 - val_loss: 1.7722 - val_accuracy: 0.4278
# Epoch 8/60
# 72/72 [==============================] - 6s 77ms/step - loss: 1.1607 - accuracy: 0.5694 - val_loss: 1.7750 - val_accuracy: 0.3861
# Epoch 9/60
# 72/72 [==============================] - 5s 76ms/step - loss: 1.1293 - accuracy: 0.5796 - val_loss: 1.7213 - val_accuracy: 0.4361
# Epoch 10/60
# 72/72 [==============================] - 5s 76ms/step - loss: 1.0560 - accuracy: 0.6148 - val_loss: 1.7763 - val_accuracy: 0.4611
# Epoch 11/60
# 72/72 [==============================] - 5s 76ms/step - loss: 1.0364 - accuracy: 0.6231 - val_loss: 1.8052 - val_accuracy: 0.4361
# Epoch 12/60
# 72/72 [==============================] - 5s 76ms/step - loss: 0.9825 - accuracy: 0.6491 - val_loss: 1.7847 - val_accuracy: 0.4667
# Epoch 13/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.8827 - accuracy: 0.6796 - val_loss: 1.9732 - val_accuracy: 0.4833
# Epoch 14/60
# 72/72 [==============================] - 5s 76ms/step - loss: 0.8519 - accuracy: 0.6787 - val_loss: 1.7237 - val_accuracy: 0.4944
# Epoch 15/60
# 72/72 [==============================] - 5s 76ms/step - loss: 0.8147 - accuracy: 0.6963 - val_loss: 1.8437 - val_accuracy: 0.4639
# Epoch 16/60
# 72/72 [==============================] - 5s 76ms/step - loss: 0.7483 - accuracy: 0.7222 - val_loss: 1.9276 - val_accuracy: 0.4944
# Epoch 17/60
# 72/72 [==============================] - 5s 76ms/step - loss: 0.7170 - accuracy: 0.7463 - val_loss: 1.9746 - val_accuracy: 0.5222
# Epoch 18/60
# 72/72 [==============================] - 5s 76ms/step - loss: 0.6728 - accuracy: 0.7583 - val_loss: 1.9912 - val_accuracy: 0.4889
# Epoch 19/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.6501 - accuracy: 0.7648 - val_loss: 2.0267 - val_accuracy: 0.5000
# Epoch 20/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.6089 - accuracy: 0.7843 - val_loss: 1.9109 - val_accuracy: 0.5194
# Epoch 21/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.5471 - accuracy: 0.8046 - val_loss: 1.8876 - val_accuracy: 0.5389
# Epoch 22/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.5398 - accuracy: 0.8083 - val_loss: 1.9211 - val_accuracy: 0.5250
# Epoch 23/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.4632 - accuracy: 0.8370 - val_loss: 2.0027 - val_accuracy: 0.5306
# Epoch 24/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.4225 - accuracy: 0.8519 - val_loss: 2.2739 - val_accuracy: 0.5306
# Epoch 25/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.4072 - accuracy: 0.8593 - val_loss: 2.2673 - val_accuracy: 0.5417
# Epoch 26/60
# 72/72 [==============================] - 6s 76ms/step - loss: 0.3953 - accuracy: 0.8630 - val_loss: 2.1650 - val_accuracy: 0.5639
# Epoch 27/60
# 72/72 [==============================] - 5s 76ms/step - loss: 0.3548 - accuracy: 0.8870 - val_loss: 2.8331 - val_accuracy: 0.5500
# Epoch 28/60
# 72/72 [==============================] - 5s 76ms/step - loss: 0.3389 - accuracy: 0.8852 - val_loss: 2.5426 - val_accuracy: 0.5417
# Epoch 29/60
# 72/72 [==============================] - 5s 76ms/step - loss: 0.2945 - accuracy: 0.9009 - val_loss: 3.0475 - val_accuracy: 0.5333
# Epoch 30/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.3099 - accuracy: 0.8889 - val_loss: 2.8676 - val_accuracy: 0.5556
# Epoch 31/60
# 72/72 [==============================] - 6s 76ms/step - loss: 0.2732 - accuracy: 0.9120 - val_loss: 3.1559 - val_accuracy: 0.5361
# Epoch 32/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.2646 - accuracy: 0.9157 - val_loss: 3.2629 - val_accuracy: 0.5472
# Epoch 33/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.2143 - accuracy: 0.9139 - val_loss: 3.4490 - val_accuracy: 0.5361
# Epoch 34/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.2227 - accuracy: 0.9250 - val_loss: 3.4398 - val_accuracy: 0.5417
# Epoch 35/60
# 72/72 [==============================] - 6s 78ms/step - loss: 0.2140 - accuracy: 0.9241 - val_loss: 3.0804 - val_accuracy: 0.5556
# Epoch 36/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.2130 - accuracy: 0.9343 - val_loss: 3.2559 - val_accuracy: 0.5694
# Epoch 37/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.1912 - accuracy: 0.9389 - val_loss: 3.9061 - val_accuracy: 0.5167
# Epoch 38/60
# 72/72 [==============================] - 5s 76ms/step - loss: 0.1824 - accuracy: 0.9472 - val_loss: 3.4834 - val_accuracy: 0.5389
# Epoch 39/60
# 72/72 [==============================] - 5s 76ms/step - loss: 0.1619 - accuracy: 0.9463 - val_loss: 3.8755 - val_accuracy: 0.5333
# Epoch 40/60
# 72/72 [==============================] - 5s 76ms/step - loss: 0.1682 - accuracy: 0.9389 - val_loss: 3.9280 - val_accuracy: 0.5444
# Epoch 41/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.1544 - accuracy: 0.9509 - val_loss: 4.4406 - val_accuracy: 0.5500
# Epoch 42/60
# 72/72 [==============================] - 6s 78ms/step - loss: 0.1513 - accuracy: 0.9500 - val_loss: 4.0395 - val_accuracy: 0.5333
# Epoch 43/60
# 72/72 [==============================] - 6s 78ms/step - loss: 0.1732 - accuracy: 0.9491 - val_loss: 4.3089 - val_accuracy: 0.5500
# Epoch 44/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.1214 - accuracy: 0.9583 - val_loss: 4.2945 - val_accuracy: 0.5333
# Epoch 45/60
# 72/72 [==============================] - 6s 78ms/step - loss: 0.1171 - accuracy: 0.9657 - val_loss: 4.4887 - val_accuracy: 0.5500
# Epoch 46/60
# 72/72 [==============================] - 6s 78ms/step - loss: 0.1155 - accuracy: 0.9694 - val_loss: 4.6134 - val_accuracy: 0.5278
# Epoch 47/60
# 72/72 [==============================] - 6s 78ms/step - loss: 0.1040 - accuracy: 0.9667 - val_loss: 4.5470 - val_accuracy: 0.5417
# Epoch 48/60
# 72/72 [==============================] - 6s 78ms/step - loss: 0.0877 - accuracy: 0.9694 - val_loss: 5.0329 - val_accuracy: 0.5528
# Epoch 49/60
# 72/72 [==============================] - 6s 79ms/step - loss: 0.1093 - accuracy: 0.9676 - val_loss: 4.5895 - val_accuracy: 0.5639
# Epoch 50/60
# 72/72 [==============================] - 6s 78ms/step - loss: 0.0948 - accuracy: 0.9676 - val_loss: 4.5606 - val_accuracy: 0.5444
# Epoch 51/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.0923 - accuracy: 0.9731 - val_loss: 4.9618 - val_accuracy: 0.5583
# Epoch 52/60
# 72/72 [==============================] - 6s 78ms/step - loss: 0.0857 - accuracy: 0.9704 - val_loss: 4.4228 - val_accuracy: 0.5556
# Epoch 53/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.1124 - accuracy: 0.9685 - val_loss: 4.5672 - val_accuracy: 0.5639
# Epoch 54/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.0530 - accuracy: 0.9843 - val_loss: 4.8844 - val_accuracy: 0.5417
# Epoch 55/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.0951 - accuracy: 0.9685 - val_loss: 5.0873 - val_accuracy: 0.5583
# Epoch 56/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.0966 - accuracy: 0.9667 - val_loss: 5.8145 - val_accuracy: 0.5444
# Epoch 57/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.0927 - accuracy: 0.9731 - val_loss: 5.0151 - val_accuracy: 0.5472
# Epoch 58/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.0515 - accuracy: 0.9824 - val_loss: 5.1648 - val_accuracy: 0.5889
# Epoch 59/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.0635 - accuracy: 0.9759 - val_loss: 5.5383 - val_accuracy: 0.5278
# Epoch 60/60
# 72/72 [==============================] - 6s 77ms/step - loss: 0.0909 - accuracy: 0.9731 - val_loss: 4.6068 - val_accuracy: 0.5667

# %%
#Show nueral net performance
print("Train Accuracy : " , model.evaluate(X_train_sc_1,y_train)[1]*100 , "%")
print("Test Accuracy : " , model.evaluate(X_test_sc_1,y_test)[1]*100 , "%")

epochs = [i for i in range(60)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0146 - accuracy: 0.9954
# Train Accuracy :  99.53703880310059 %
# 12/12 [==============================] - 0s 24ms/step - loss: 4.6068 - accuracy: 0.5667
# Test Accuracy :  56.66666626930237 %

# %%
#Predict on test data
y_predictions = model.predict(X_test_sc_1).argmax(axis=1)

#Print classification report
print(classification_report(y_test,y_predictions, target_names=levels))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.82      0.67      0.74        48
#         Calm       0.63      0.73      0.67        51
#      Disgust       0.59      0.54      0.57        48
#      Fearful       0.49      0.40      0.44        47
#        Happy       0.46      0.55      0.50        49
#      Neutral       0.50      0.31      0.38        26
#          Sad       0.44      0.66      0.53        41
#     Suprised       0.65      0.56      0.60        50
#
#     accuracy                           0.57       360
#    macro avg       0.57      0.55      0.55       360
# weighted avg       0.58      0.57      0.57       360

# %%
#Plot confusion matrix
cf_matrix(y_predictions,y_test)
