# %% [markdown]
# # <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # **Capstone Project: Audio Classification Of Emotions**
#
# # Modeling on MFCC

# %%
#Mount Drive

from google.colab import drive
drive.mount('/content/My_Drive/')
# Out:
# Drive already mounted at /content/My_Drive/; to attempt to forcibly remount, call drive.mount("/content/My_Drive/", force_remount=True).

# %% [markdown]
# ## Imports

# %%
#Import basic, plotting libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns


# %matplotlib inline

#Import SK-Learn Libraries
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier as R_Forest
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier as KNNClassifier
from sklearn import svm
from sklearn.preprocessing import LabelEncoder, StandardScaler, RobustScaler

#Import Keras Layers
import keras
from keras import layers
from keras import models
from keras.layers import GlobalAveragePooling1D, Dense, MaxPooling1D, Conv1D, Flatten, Dropout
from keras.models import Sequential
from keras.layers.core import Activation, Dense 
from keras.layers import BatchNormalization
from tensorflow.keras.optimizers import RMSprop
from keras.layers import GaussianNoise

# %% [markdown]
# ## Functions

# %%
def cf_matrix(y_preds, y_test):
  '''This function creates a confusion matrix on our data'''
  
  cf_matrix = confusion_matrix(y_preds, y_test)
  cmn = cf_matrix.astype('float') / cf_matrix.sum(axis=1)[:, np.newaxis]
  fig, ax = plt.subplots(figsize=(10,10))
  labels = ['Angry', 'Calm', 'Disgust', 'Fearful', 'Happy', 'Neutral', 'Sad', 'Suprised']
  sns.heatmap(cmn, linewidths=1, annot=True, ax=ax, fmt='.2f', cmap="OrRd")
  ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix')
  ax.xaxis.set_ticklabels(labels); ax.yaxis.set_ticklabels(labels);

# %%
#Set a random seed for reproducibility.
np.random.seed(42)

# %%
#Read_CSV
df = pd.read_csv('Data/DataFrames/MFCC_Data.csv')

# %%
#Encoded Labels
levels = ['Angry', 'Calm', 'Disgust', 'Fearful', 'Happy', 'Neutral', 'Sad', 'Suprised']

#Show dataframe
df.head(2)
# Out:
#                        path  actor  emotion_id  ...        37        38        39
# 0  03-01-05-01-02-01-16.wav     16           5  ...  2.299387 -0.806499  2.516651
# 1  03-01-06-01-02-02-16.wav     16           6  ...  1.108818  0.153405  0.344702
#
# [2 rows x 50 columns]

# %%
le = LabelEncoder()
df['encoded_label']= le.fit_transform(df['label'])

# %%
#Select X and y features
X = df.iloc[:, 10:].values
y = df['encoded_label'].values

print(X.shape)
print(y.shape)
# Out:
# (1440, 40)
# (1440,)

# %%
#Add as array
X = np.asarray(X)
y = np.asarray(y)


X.shape, y.shape
# Out:
# ((1440, 40), (1440,))

# %%
#Create train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, shuffle = True)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1080, 40), (1080,), (360, 40), (360,))

# %%
#Scale X_training Data
sc = StandardScaler()

X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
#Expand dimensions for nueral net
X_train_sc_1 = np.expand_dims(X_train_sc, axis=2)
X_test_sc_1 = np.expand_dims(X_test_sc, axis=2)

X_train_sc_1.shape, X_test_sc_1.shape
# Out:
# ((1080, 40, 1), (360, 40, 1))

# %% [markdown]
# ## Models

# %%
SVM = svm.SVC()

# %%
SVM.fit(X_train_sc, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_predSVM = SVM.predict(X_test_sc)

# %%
print(classification_report(y_test,y_predSVM,target_names=levels))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.83      0.71      0.76        48
#         Calm       0.65      0.82      0.72        51
#      Disgust       0.62      0.62      0.62        48
#      Fearful       0.67      0.66      0.67        47
#        Happy       0.65      0.45      0.53        49
#      Neutral       0.33      0.04      0.07        26
#          Sad       0.43      0.63      0.51        41
#     Suprised       0.65      0.80      0.71        50
#
#     accuracy                           0.63       360
#    macro avg       0.60      0.59      0.58       360
# weighted avg       0.62      0.63      0.61       360

# %%
cf_matrix(y_predSVM,y_test)

# %% [markdown]
# #### K-Nearest Neighbors

# %%
clf = KNNClassifier()
clf.fit(X_train_sc, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_predKNN = clf.predict(X_test_sc)

# %%
print(classification_report(y_test,y_predKNN,target_names=levels))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.61      0.58      0.60        48
#         Calm       0.63      0.90      0.74        51
#      Disgust       0.65      0.58      0.62        48
#      Fearful       0.48      0.53      0.51        47
#        Happy       0.47      0.37      0.41        49
#      Neutral       0.50      0.35      0.41        26
#          Sad       0.50      0.29      0.37        41
#     Suprised       0.62      0.82      0.71        50
#
#     accuracy                           0.57       360
#    macro avg       0.56      0.55      0.54       360
# weighted avg       0.56      0.57      0.56       360

# %%
cf_matrix(y_predKNN,y_test)

# %% [markdown]
# #### Random Forest Classifier

# %%
rforest = R_Forest(criterion="gini", 
                   max_depth=5, 
                   max_features="log2",  
                   min_samples_leaf = 3, 
                   min_samples_split = 20, 
                   n_estimators= 22000, 
                   )

# %%
#Fit Random forest
rforest.fit(X_train_sc, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=5, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=3, min_samples_split=20,
#                        min_weight_fraction_leaf=0.0, n_estimators=22000,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#Get predictions
y_pred = rforest.predict(X_test_sc)

# %%
#Print classification report
print(classification_report(y_test,y_pred,target_names=levels))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.60      0.58      0.59        48
#         Calm       0.51      0.90      0.65        51
#      Disgust       0.46      0.48      0.47        48
#      Fearful       0.67      0.51      0.58        47
#        Happy       0.50      0.27      0.35        49
#      Neutral       0.00      0.00      0.00        26
#          Sad       0.25      0.32      0.28        41
#     Suprised       0.47      0.54      0.50        50
#
#     accuracy                           0.48       360
#    macro avg       0.43      0.45      0.43       360
# weighted avg       0.46      0.48      0.46       360
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Plot confusion matrix
cf_matrix(y_pred,y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """

# %% [markdown]
# #### Decision Tree Classifier

# %%
#Instantiate decision tree 
dtree = DecisionTreeClassifier()

# %%
#Fit decision tree
dtree.fit(X_train_sc, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#Predict data
y_preds = dtree.predict(X_test_sc)

# %%
#Print classification report
print(classification_report(y_test,y_preds,target_names=levels))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.57      0.56      0.57        48
#         Calm       0.47      0.45      0.46        51
#      Disgust       0.35      0.38      0.36        48
#      Fearful       0.45      0.47      0.46        47
#        Happy       0.45      0.35      0.39        49
#      Neutral       0.30      0.31      0.30        26
#          Sad       0.29      0.34      0.31        41
#     Suprised       0.41      0.40      0.40        50
#
#     accuracy                           0.41       360
#    macro avg       0.41      0.41      0.41       360
# weighted avg       0.42      0.41      0.42       360

# %%
#Plot confusion matrix
cf_matrix(y_preds,y_test)

# %% [markdown]
# #### Convolutional Nueral Net (CNN)

# %%
#Develop model
model = models.Sequential()
model.add(Conv1D(264, kernel_size=5, strides=1,  activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(MaxPooling1D(pool_size=5, strides = 2))
model.add(GaussianNoise(0.1))
model.add(Conv1D(128, kernel_size=5, strides=1, activation='relu'))
model.add(Dropout(0.2))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(8, activation='softmax'))


 # Select loss function and optimizer
model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 36, 264)           1584
# _________________________________________________________________
# dropout (Dropout)            (None, 36, 264)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 16, 264)           0
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 16, 264)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 12, 128)           169088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 128)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                98368
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 520
# =================================================================
# Total params: 269,560
# Trainable params: 269,560
# Non-trainable params: 0
# _________________________________________________________________

# %%
#fit and train model
history = model.fit(
    X_train_sc_1,
    y_train,
    epochs=60,
    batch_size=15,
    validation_data=(X_test_sc_1, y_test)
  )
# Out:
# Epoch 1/60
# 72/72 [==============================] - 3s 25ms/step - loss: 2.0036 - accuracy: 0.1704 - val_loss: 1.9167 - val_accuracy: 0.2444
# Epoch 2/60
# 72/72 [==============================] - 2s 22ms/step - loss: 1.9190 - accuracy: 0.2315 - val_loss: 1.8880 - val_accuracy: 0.2750
# Epoch 3/60
# 72/72 [==============================] - 2s 22ms/step - loss: 1.8743 - accuracy: 0.2509 - val_loss: 1.8512 - val_accuracy: 0.2833
# Epoch 4/60
# 72/72 [==============================] - 2s 22ms/step - loss: 1.8147 - accuracy: 0.3148 - val_loss: 1.7892 - val_accuracy: 0.3250
# Epoch 5/60
# 72/72 [==============================] - 2s 22ms/step - loss: 1.7388 - accuracy: 0.3259 - val_loss: 1.7485 - val_accuracy: 0.3500
# Epoch 6/60
# 72/72 [==============================] - 2s 22ms/step - loss: 1.6726 - accuracy: 0.3778 - val_loss: 1.6253 - val_accuracy: 0.4278
# Epoch 7/60
# 72/72 [==============================] - 2s 22ms/step - loss: 1.5875 - accuracy: 0.4130 - val_loss: 1.5811 - val_accuracy: 0.4306
# Epoch 8/60
# 72/72 [==============================] - 2s 22ms/step - loss: 1.5386 - accuracy: 0.4231 - val_loss: 1.5491 - val_accuracy: 0.4389
# Epoch 9/60
# 72/72 [==============================] - 2s 22ms/step - loss: 1.4363 - accuracy: 0.4657 - val_loss: 1.4709 - val_accuracy: 0.4639
# Epoch 10/60
# 72/72 [==============================] - 2s 22ms/step - loss: 1.3642 - accuracy: 0.4963 - val_loss: 1.4137 - val_accuracy: 0.4833
# Epoch 11/60
# 72/72 [==============================] - 2s 22ms/step - loss: 1.3261 - accuracy: 0.5019 - val_loss: 1.4028 - val_accuracy: 0.5361
# Epoch 12/60
# 72/72 [==============================] - 2s 22ms/step - loss: 1.2368 - accuracy: 0.5546 - val_loss: 1.3573 - val_accuracy: 0.5417
# Epoch 13/60
# 72/72 [==============================] - 2s 22ms/step - loss: 1.1811 - accuracy: 0.5861 - val_loss: 1.2885 - val_accuracy: 0.5500
# Epoch 14/60
# 72/72 [==============================] - 2s 22ms/step - loss: 1.1097 - accuracy: 0.5926 - val_loss: 1.3066 - val_accuracy: 0.5389
# Epoch 15/60
# 72/72 [==============================] - 2s 23ms/step - loss: 1.0334 - accuracy: 0.6185 - val_loss: 1.3432 - val_accuracy: 0.5306
# Epoch 16/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.9806 - accuracy: 0.6500 - val_loss: 1.2532 - val_accuracy: 0.5861
# Epoch 17/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.9187 - accuracy: 0.6593 - val_loss: 1.2752 - val_accuracy: 0.5722
# Epoch 18/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.8665 - accuracy: 0.6889 - val_loss: 1.2621 - val_accuracy: 0.5972
# Epoch 19/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.8105 - accuracy: 0.6870 - val_loss: 1.2782 - val_accuracy: 0.5833
# Epoch 20/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.7179 - accuracy: 0.7463 - val_loss: 1.2684 - val_accuracy: 0.6000
# Epoch 21/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.7029 - accuracy: 0.7491 - val_loss: 1.2227 - val_accuracy: 0.5972
# Epoch 22/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.6252 - accuracy: 0.7750 - val_loss: 1.2512 - val_accuracy: 0.6139
# Epoch 23/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.5874 - accuracy: 0.7759 - val_loss: 1.3699 - val_accuracy: 0.5639
# Epoch 24/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.5154 - accuracy: 0.8269 - val_loss: 1.1859 - val_accuracy: 0.6028
# Epoch 25/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.4605 - accuracy: 0.8324 - val_loss: 1.3276 - val_accuracy: 0.5917
# Epoch 26/60
# 72/72 [==============================] - 2s 23ms/step - loss: 0.4258 - accuracy: 0.8565 - val_loss: 1.2545 - val_accuracy: 0.6333
# Epoch 27/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.4155 - accuracy: 0.8583 - val_loss: 1.3057 - val_accuracy: 0.6222
# Epoch 28/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.3702 - accuracy: 0.8713 - val_loss: 1.3104 - val_accuracy: 0.6361
# Epoch 29/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.3314 - accuracy: 0.8880 - val_loss: 1.2934 - val_accuracy: 0.6278
# Epoch 30/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.3261 - accuracy: 0.8778 - val_loss: 1.4150 - val_accuracy: 0.6167
# Epoch 31/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.3017 - accuracy: 0.8981 - val_loss: 1.3251 - val_accuracy: 0.6222
# Epoch 32/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.2593 - accuracy: 0.9222 - val_loss: 1.3792 - val_accuracy: 0.6361
# Epoch 33/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.2783 - accuracy: 0.8981 - val_loss: 1.3143 - val_accuracy: 0.6250
# Epoch 34/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.2520 - accuracy: 0.9167 - val_loss: 1.3420 - val_accuracy: 0.6306
# Epoch 35/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.2343 - accuracy: 0.9213 - val_loss: 1.4235 - val_accuracy: 0.6389
# Epoch 36/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1976 - accuracy: 0.9287 - val_loss: 1.4829 - val_accuracy: 0.6278
# Epoch 37/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1863 - accuracy: 0.9333 - val_loss: 1.4449 - val_accuracy: 0.6444
# Epoch 38/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1620 - accuracy: 0.9565 - val_loss: 1.5677 - val_accuracy: 0.6500
# Epoch 39/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1833 - accuracy: 0.9333 - val_loss: 1.5046 - val_accuracy: 0.6306
# Epoch 40/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1703 - accuracy: 0.9389 - val_loss: 1.5583 - val_accuracy: 0.6444
# Epoch 41/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1647 - accuracy: 0.9454 - val_loss: 1.5841 - val_accuracy: 0.6361
# Epoch 42/60
# 72/72 [==============================] - 2s 23ms/step - loss: 0.1887 - accuracy: 0.9398 - val_loss: 1.5138 - val_accuracy: 0.6389
# Epoch 43/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1370 - accuracy: 0.9556 - val_loss: 1.6132 - val_accuracy: 0.6250
# Epoch 44/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1533 - accuracy: 0.9509 - val_loss: 1.4804 - val_accuracy: 0.6528
# Epoch 45/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1695 - accuracy: 0.9509 - val_loss: 1.5489 - val_accuracy: 0.6444
# Epoch 46/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1006 - accuracy: 0.9713 - val_loss: 1.6781 - val_accuracy: 0.6472
# Epoch 47/60
# 72/72 [==============================] - 2s 23ms/step - loss: 0.1179 - accuracy: 0.9620 - val_loss: 1.6414 - val_accuracy: 0.6500
# Epoch 48/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1398 - accuracy: 0.9509 - val_loss: 1.6573 - val_accuracy: 0.6278
# Epoch 49/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1149 - accuracy: 0.9593 - val_loss: 1.7087 - val_accuracy: 0.6333
# Epoch 50/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1246 - accuracy: 0.9611 - val_loss: 1.7742 - val_accuracy: 0.6361
# Epoch 51/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.1486 - accuracy: 0.9509 - val_loss: 1.6848 - val_accuracy: 0.6000
# Epoch 52/60
# 72/72 [==============================] - 2s 23ms/step - loss: 0.1264 - accuracy: 0.9583 - val_loss: 1.6344 - val_accuracy: 0.6472
# Epoch 53/60
# 72/72 [==============================] - 2s 23ms/step - loss: 0.1146 - accuracy: 0.9713 - val_loss: 1.6641 - val_accuracy: 0.6556
# Epoch 54/60
# 72/72 [==============================] - 2s 23ms/step - loss: 0.1090 - accuracy: 0.9583 - val_loss: 1.6992 - val_accuracy: 0.6417
# Epoch 55/60
# 72/72 [==============================] - 2s 23ms/step - loss: 0.0708 - accuracy: 0.9759 - val_loss: 1.6717 - val_accuracy: 0.6667
# Epoch 56/60
# 72/72 [==============================] - 2s 23ms/step - loss: 0.0884 - accuracy: 0.9722 - val_loss: 1.8175 - val_accuracy: 0.6250
# Epoch 57/60
# 72/72 [==============================] - 2s 23ms/step - loss: 0.1024 - accuracy: 0.9648 - val_loss: 1.6593 - val_accuracy: 0.6472
# Epoch 58/60
# 72/72 [==============================] - 2s 23ms/step - loss: 0.1182 - accuracy: 0.9574 - val_loss: 1.7428 - val_accuracy: 0.6278
# Epoch 59/60
# 72/72 [==============================] - 2s 23ms/step - loss: 0.0996 - accuracy: 0.9620 - val_loss: 1.7898 - val_accuracy: 0.6528
# Epoch 60/60
# 72/72 [==============================] - 2s 22ms/step - loss: 0.0816 - accuracy: 0.9694 - val_loss: 1.7579 - val_accuracy: 0.6361

# %%
#Show nueral net performance
print("Train Accuracy : " , model.evaluate(X_train_sc_1,y_train)[1]*100 , "%")
print("Test Accuracy : " , model.evaluate(X_test_sc_1,y_test)[1]*100 , "%")

epochs = [i for i in range(60)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0222 - accuracy: 0.9972
# Train Accuracy :  99.72222447395325 %
# 12/12 [==============================] - 0s 9ms/step - loss: 1.7579 - accuracy: 0.6361
# Test Accuracy :  63.61111402511597 %

# %%
#Predict on test data
y_predictions = model.predict(X_test_sc_1).argmax(axis=1)

#Print classification report
print(classification_report(y_test,y_predictions, target_names=levels))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.79      0.65      0.71        48
#         Calm       0.75      0.76      0.76        51
#      Disgust       0.67      0.62      0.65        48
#      Fearful       0.60      0.66      0.63        47
#        Happy       0.46      0.47      0.46        49
#      Neutral       0.71      0.65      0.68        26
#          Sad       0.49      0.54      0.51        41
#     Suprised       0.68      0.72      0.70        50
#
#     accuracy                           0.64       360
#    macro avg       0.64      0.63      0.64       360
# weighted avg       0.64      0.64      0.64       360

# %%
#Plot confusion matrix
cf_matrix(y_predictions,y_test)

# %%
#Save Model

save_format='h5'
model.save("Chosen_Model.h5")
